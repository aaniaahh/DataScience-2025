# %% [markdown]
# <a href="https://colab.research.google.com/github/aaniaahh/DataScience-2025/blob/main/Completed/Notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Variable, Data Type, and Operator Review
# ### Aniah Myles
# This notebook helps you practice basic Python syntax.

# %%
# 🔧 Define Variables
x = 22
y = 4.5
z = 'hello'
b = True
print(x, y, z, b)

# %% [markdown]
# ### ✅ What is the type of each variable above?
# Use the `type()` function below:

# %%
print(type(x))
print(type(y))
print(type(z))
print(type(b))

# %% [markdown]
# ### ⚖️ Comparison Operators
# Fill in the blanks:

# %%
# True or False?
print(x ___ y)
print(z == 'hello')

# %% [markdown]
# ### ➗ Arithmetic Practice

# %%
a = 7
b = 3
print('Add:', a + b)
print('Subtract', a - b)
print('Divide:', a / b)
print('Modulus:', a % b)

# %% [markdown]
# ### 🧠 Logical Operators

# %%
print(True and False)
print(True or False)
print(not False)
