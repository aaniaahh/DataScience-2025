# %% [markdown]
# <a href="https://colab.research.google.com/github/aaniaahh/DataScience-2025/blob/main/Completed/05-Foundations/05_plotting_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📈 05 - Plotting Basics
# Visualization is a core part of data science.
#
# In this notebook you will learn:
#
# * Setting up Matplotlib for inline plotting
# * Creating simple line, scatter, and bar plots
# * Customizing titles, labels, and legends
# * Why visuals matter in data storytelling
#
# ## 1. Setup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2. Line Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the variables
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Display the information
plt.plot(x, y, label="sin(x)")
plt.title("Sine Function")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.legend()
plt.show()

# %% [markdown]
# ✅ **Your Turn:** Plot cos(x) on the same graph with a different color and label.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the variables
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Customize the sets
plt.plot(x, y1, label="sin(x)", color = "yellow")
plt.plot(x, y2, label="cos(x)", color = "blue")

# Display the sets
plt.title("Sine and Cosine Function")
plt.xlabel("x")
plt.ylabel("Funtion Value")
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Scatter Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the variables
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 300 * np.random.rand(50)
colors = np.random.rand(50)

# Customize and display the sets
plt.scatter(x, y, s=sizes, c=colors, alpha=0.6, cmap='viridis')
plt.title("Scatter Plot Example")
plt.xlabel("x")
plt.ylabel("y")
plt.colorbar(label="color scale")
plt.show()

# %% [markdown]
# ✅ **Your Turn:** Generate two sets of random points and plot them in different colors on the same scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create two sets
x1 = np.random.rand(50)
y1 = np.random.rand(50)

x2 = np.random.rand(50)
y2 = np.random.rand(50)

# Create the sizes
sizes = 300 * np.random.rand(50)

# Create scatter plot
plt.scatter(x1, y1, s=sizes, color="brown", label='Set 1')
plt.scatter(x2, y2, s=sizes, color="green", label='Set 2')

# Display the sets
plt.title("Scatter Plot Example")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 4. Bar Plot

# %%
# Create the variables
categories = ["A", "B", "C", "D"]
values = [5, 7, 3, 8]

# Display the sets
plt.bar(categories, values)
plt.title("Bar Plot Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ✅ **Your Turn:** Create your own bar chart with at least 4 categories (e.g., favorite foods, courses, or hobbies).

# %%
# Create Variables
majors = ["Computer Science", "Mathematics", "Nursing", "Kinesiology"]
students = [150, 90, 200, 110]

# Display the information
plt.bar(majors, students, color="orange")
plt.title("Bar Plot")
plt.xlabel("Majors")
plt.ylabel("# of Students")
plt.show()

# %% [markdown]
# ## 5. Customizing Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the variables
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)


# Customize and display the sets
plt.plot(x, y1, label="sin(x)", linestyle="--", color="blue")
plt.plot(x, y2, label="cos(x)", linestyle=":", color="red")
plt.title("Customized Line Plot")
plt.xlabel("x (radians)")
plt.ylabel("value")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ✅ **Your Turn:** Customize your own plot with labels, legend, and grid lines.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the line
x = np.linspace(0, 2*np.pi, 100)
y1 = np.tan(x)
y2 = np.cos(x)

# Customize the sets
plt.plot(x, y1, label="tan(x)", linestyle="--", color="pink")
plt.plot(x, y2, label="cos(x)", linestyle=":", color="blue")

# Display the sets
plt.title("Customized Line Plot")
plt.xlabel("radians")
plt.ylabel("value")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Summary
# * `%matplotlib inline` makes plots display inside the notebook.
# * Line, scatter, and bar plots are the most common basics.
# * Titles, labels, legends, and grids improve readability.
# * Visuals tell stories about data more effectively than raw numbers.
